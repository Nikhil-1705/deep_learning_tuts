# %% [markdown]
# ### Authorization methods
#
# #### API Keys
# Anybody having your API key can impersonate you, good where client data is not involved, best usecase is public APIs
# #### JWT (Json Web Token)
#
# #### OAuth 2.0
# Used when you see sign in with google / Facebook
# ![OAuth 2.0](/Images/OAuth2_0.png)
