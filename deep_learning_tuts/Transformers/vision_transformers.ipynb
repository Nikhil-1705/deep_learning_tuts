# %% [markdown]
# ### Vision Transformers

# %% [markdown]
# What Happens step by step?
#
# 1) Split an image into patches
#
# 2) Flatten the patches
#
# 3) Produce lower-dimensional linear embeddings from the flattened patches
#
# 4) Add positional embeddings
#
# 5) Feed the sequence as an input to a standard transformer encoder
#
# 6) Pretrain the model with image labels (fully supervised on a huge dataset)
#
# 4) Finetune on the downstream dataset for image classification
#
# Specifically, if ViT is trained on datasets with more than 14M (at least :P) images it can approach or beat state-of-the-art CNNs.
# ViT is pretrained on the large dataset and then fine-tuned to small ones. The only modification is to discard the prediction head (MLP head) and attach a new
# D×K
# D×K linear layer, where K is the number of classes of the small dataset.

# %% [markdown]
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHlqazQ1NGplODJ6ZmoxZGI4NDM4OTd2Y2ZteDdlcHF3NzNsdjh6NyZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/ATsWtUsuuFRfq8OhZ7/giphy.gif" alt="Vision Transformer Animation" style="width: 480px;"/>

# %% [markdown]
# ### ViT Variants

# %% [markdown]
# <img src="https://theaisummer.com/static/156f6be8c232bb0b03d4793b2be2fbad/57dc1/vit-models-description-table.png" alt="ViT Models Description Table" style="width: 100%;"/>
