# %% [markdown]
# # 🔌 Types of APIs
#
# ---
#
# ## 1. REST API *(Representational State Transfer)*
#
# REST is the most widely used API style. It is **stateless** (servers don't store client state) and uses standard HTTP methods.
#
# | Method | Idempotent? | Description |
# |--------|-------------|-------------|
# | `GET` | ✅ Yes | Fetch a resource |
# | `DELETE` | ✅ Yes | Delete a resource (deleting user 123 twice → same result) |
# | `PUT` | ✅ Yes | Update a resource |
# | `POST` | ❌ No | Create a resource (calling twice may create two records) |
#
# > **Idempotent** means making the same request multiple times produces the same state.
#
# **How a REST request flows:**
#
# Client → DNS Resolution → Load Balancer → API Server → Database → JSON Response

# %% [markdown]
# ---
#
# ## 2. SOAP *(Simple Object Access Protocol)*
#
# - Uses **XML** for communication
# - Stricter rules, more secure, reliable
# - Has independent error handling
# - Works over: `HTTP`, `HTTPS`, `TCP`, `SMTP`
#
# ---
#
# ## 3. gRPC *(Google Remote Procedure Call)*
#
# Fast and lightweight — data travels as **binary** (Protocol Buffers), making it **~7–10× faster than REST**.
#
# | Mode | Use Case |
# |------|----------|
# | Simple request-response | Standard API calls |
# | Server streaming | Live updates to client |
# | Client streaming | Sending continuous data |
# | Bidirectional streaming | Real-time chat |
#
# ---
#
# ## 4. GraphQL
#
# REST APIs suffer from **over-fetching** or **under-fetching** data. GraphQL lets you query exactly what you need.
#
# **Problems GraphQL solves:**
# - ❌ Overfetching
# - ❌ Multiple round-trip requests
# - ❌ Inefficient data transfer & parsing
# - ❌ Too many endpoints
#
# ---
#
# ## 5. Webhooks *(Reverse API)*
#
# Instead of you requesting data, the **server pushes data to you** when something happens.
#
# > Think of it as: *"Don't call us, we'll call you."*
#
# Used for: keeping systems in sync, automations, event-driven pipelines.
#
# ---
#
# ## 6. WebSockets
#
# Establishes a **persistent, two-way connection** between client and server — no repeated requests needed.
#
# **Common use cases:**
# - Multiplayer online games
# - Real-time chat applications
# - Live dashboards
#
# ---
#
# ## When to Use Which?
#
# ![API Comparison](Images/when_to_use_which_API.png)
